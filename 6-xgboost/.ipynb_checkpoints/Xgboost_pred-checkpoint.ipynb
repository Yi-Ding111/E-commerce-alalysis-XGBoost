# %%
import pymysql
import pymysql.cursors
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#connect my database

# %%
mydb = pymysql.connect(
    host='127.0.0.1',
    port=3306,
    user='root',
    passwd='',
    db='action'
    )

# %%
#merge table information

# %%
cursor=mydb.cursor()
all_info_table_train='CREATE TABLE all_info_table_train AS\
                SELECT P.cate,A.user_id,A.sku_id,A.action_time,P.brand,P.shop_id,A.type,U.sex,U.age,U.user_lv_cd,U.city_level\
                FROM action AS A\
                JOIN product AS P ON P.sku_id=A.sku_id\
                JOIN user AS U ON U.user_id=A.user_id\
                WHERE A.type=2 AND A.action_time BETWEEN "2018-02-01 00:00:00" AND "2018-04-10 00:00:00"'
cursor.execute(all_info_table_train)
myresult_train=cursor.fetchall()

# %%
cursor2=mydb.cursor()
all_info_table_test='CREATE TABLE all_info_table_test AS\
                SELECT P.cate,A.user_id,A.sku_id,A.action_time,P.brand,P.shop_id,A.type,U.sex,U.age,U.user_lv_cd,U.city_level\
                FROM action AS A\
                JOIN product AS P ON P.sku_id=A.sku_id\
                JOIN user AS U ON U.user_id=A.user_id\
                WHERE A.type=2 AND A.action_time BETWEEN "2018-04-10 00:00:00" AND "2018-04-16 00:00:00"'
cursor2.execute(all_info_table_test)
myresult_test=cursor.fetchall()

# %%
cursor.close()

# %%
top10_all_info_table_train='SELECT *\
                            FROM all_info_table_train\
                            limit 10'
sql_top_10_all_info_table_train=pd.read_sql_query(top10_all_info_table_train,mydb)
print(sql_top_10_all_info_table_train)
# Out:
#    cate  user_id  sku_id            action_time  brand  shop_id  type  sex  \
# 0    79   660257  282037  2018-02-08 15:05:37.0   4854     5338     2  1.0
# 1    79  1008776   31647  2018-03-02 01:02:08.0  10511     9665     2  0.0
# 2    79  1569797  141162  2018-02-06 22:32:30.0   4854       79     2  1.0
# 3    79  1066676  102904  2018-03-08 10:22:09.0   1226     7129     2  1.0
# 4    79  1314628  102417  2018-02-05 11:47:45.0   5700     1553     2  1.0
# 5    79   982912  264665  2018-02-18 16:19:44.0   1898     1182     2  0.0
# 6    79   260858  307497  2018-02-01 19:29:26.0   5206     9665     2  0.0
# 7    79  1123179  274889  2018-03-18 16:26:49.0   2564     6710     2  1.0
# 8    79   148013   47151  2018-02-21 18:48:56.0   2564     1095     2  1.0
# 9    79   399810  270064  2018-03-04 11:47:11.0   4361     5896     2  1.0
#
#    age  user_lv_cd city_level
# 0  5.0           1
# 1  6.0           7        4.0
# 2  5.0           5        4.0
# 3  6.0           7        1.0
# 4  5.0           5        1.0
# 5  5.0           5        1.0
# 6  5.0           5        1.0
# 7  5.0           5        1.0
# 8  5.0           5        1.0
# 9  5.0           5        4.0

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score as AUC
from sklearn.metrics import mean_absolute_error
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from scipy import stats
from copy import deepcopy
import csv
import os

# %%
#load dataset

# %%
train_df=pd.read_csv('/Users/charles/Desktop/consumer/all_info_table_train.csv')
test_df=pd.read_csv('/Users/charles/Desktop/consumer/all_info_table_test.csv')

# %%
train_df.head(5)
# Out:
#    cate  user_id  sku_id            action_time  brand  shop_id  type  sex  \
# 0    79   660257  282037  2018-02-08 15:05:37.0   4854     5338     2  1.0
# 1    79  1008776   31647  2018-03-02 01:02:08.0  10511     9665     2  0.0
# 2    79  1569797  141162  2018-02-06 22:32:30.0   4854       79     2  1.0
# 3    79  1066676  102904  2018-03-08 10:22:09.0   1226     7129     2  1.0
# 4    79  1314628  102417  2018-02-05 11:47:45.0   5700     1553     2  1.0
#
#    age  user_lv_cd  city_level
# 0  5.0           1         NaN
# 1  6.0           7         4.0
# 2  5.0           5         4.0
# 3  6.0           7         1.0
# 4  5.0           5         1.0

# %%
test_df.head(5)
# Out:
#    cate  user_id  sku_id            action_time  brand  shop_id  type  sex  \
# 0    79   537520   58984  2018-04-14 18:44:53.0   2564     1095     2  NaN
# 1    19  1195693  261922  2018-04-14 17:48:01.0   7357     4059     2  1.0
# 2    27  1074877  134144  2018-04-10 16:15:11.0   6588     3663     2  0.0
# 3    79   158811  114345  2018-04-12 13:19:58.0   6574     4071     2  1.0
# 4    72   852571  219951  2018-04-10 23:18:54.0   3746     7196     2 -1.0
#
#    age  user_lv_cd  city_level
# 0  NaN           5         NaN
# 1  5.0           1         NaN
# 2  5.0           7         1.0
# 3  5.0           5         1.0
# 4  5.0           6         1.0

# %%
train_df.shape
# Out:
# (1978964, 11)

# %%
test_df.shape
# Out:
# (184682, 11)

# %%
train_df.describe()
# Out:
#                cate       user_id        sku_id         brand       shop_id  \
# count  1.978964e+06  1.978964e+06  1.978964e+06  1.978964e+06  1.978964e+06
# mean   4.021845e+01  8.038331e+05  1.903919e+05  5.080010e+03  5.171412e+03
# std    2.556868e+01  4.643364e+05  1.087221e+05  3.222402e+03  3.007510e+03
# min    1.000000e+00  1.000000e+00  1.300000e+01  1.000000e+00  1.000000e+00
# 25%    2.000000e+01  4.018278e+05  9.748900e+04  2.484000e+03  2.491000e+03
# 50%    3.400000e+01  8.035870e+05  1.889780e+05  4.491000e+03  5.172000e+03
# 75%    6.900000e+01  1.206099e+06  2.856360e+05  7.954000e+03  7.831000e+03
# max    8.100000e+01  1.608707e+06  3.784560e+05  1.119900e+04  1.039900e+04
#
#             type           sex           age    user_lv_cd    city_level
# count  1978964.0  1.978066e+06  1.976863e+06  1.978964e+06  1.977190e+06
# mean         2.0  4.282981e-01  4.644960e+00  4.525498e+00  3.319738e+00
# std          0.0  5.065627e-01  1.467262e+00  2.379927e+00  1.416239e+00
# min          2.0 -1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%          2.0  0.000000e+00  4.000000e+00  1.000000e+00  3.000000e+00
# 50%          2.0  0.000000e+00  5.000000e+00  5.000000e+00  4.000000e+00
# 75%          2.0  1.000000e+00  6.000000e+00  6.000000e+00  4.000000e+00
# max          2.0  1.000000e+00  6.000000e+00  7.000000e+00  6.000000e+00

# %%
#find null value

# %%
pd.isnull(train_df).values.any()
# Out:
# True

# %%
#there is existing null vaule in train dataset

# %%
#clean null values

# %%
pd.isnull(train_df['cate']).values.any()
# Out:
# False

# %%
pd.isnull(train_df['user_id']).values.any()
# Out:
# False

# %%
pd.isnull(train_df['sku_id']).values.any()
# Out:
# False

# %%
pd.isnull(train_df['brand']).values.any()
# Out:
# False

# %%
pd.isnull(train_df['shop_id']).values.any()
# Out:
# False

# %%
pd.isnull(train_df['sex']).values.any()
# Out:
# True

# %%
train_df['sex'].plot(kind='hist')
plt.title('sex distribution')
plt.xlabel('sex')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
pd.isnull(train_df['sex']).value_counts()
# Out:
# False    1978066
# True         898
# Name: sex, dtype: int64

# %%
#the number is small, we delete them directly

# %%
train_df.dropna(subset=['sex'],how='any',inplace=True)

# %%
pd.isnull(train_df['age']).value_counts()
# Out:
# False    1976863
# True        1203
# Name: age, dtype: int64

# %%
train_df.dropna(subset=['age'],how='any',inplace=True)

# %%
pd.isnull(train_df['user_lv_cd']).value_counts()
# Out:
# False    1976863
# Name: user_lv_cd, dtype: int64

# %%
pd.isnull(train_df['city_level']).value_counts()
# Out:
# False    1975989
# True         874
# Name: city_level, dtype: int64

# %%
train_df.dropna(subset=['city_level'],how='any',inplace=True)

# %%
train_df.describe()
# Out:
#                cate       user_id        sku_id         brand       shop_id  \
# count  1.975989e+06  1.975989e+06  1.975989e+06  1.975989e+06  1.975989e+06
# mean   4.022768e+01  8.038508e+05  1.903757e+05  5.081174e+03  5.170531e+03
# std    2.556894e+01  4.643388e+05  1.087322e+05  3.222303e+03  3.007234e+03
# min    1.000000e+00  1.000000e+00  1.300000e+01  1.000000e+00  1.000000e+00
# 25%    2.000000e+01  4.018390e+05  9.745500e+04  2.484000e+03  2.491000e+03
# 50%    3.400000e+01  8.035930e+05  1.889230e+05  4.491000e+03  5.166000e+03
# 75%    6.900000e+01  1.206128e+06  2.856360e+05  7.954000e+03  7.831000e+03
# max    8.100000e+01  1.608707e+06  3.784560e+05  1.119900e+04  1.039900e+04
#
#             type           sex           age    user_lv_cd    city_level
# count  1975989.0  1.975989e+06  1.975989e+06  1.975989e+06  1.975989e+06
# mean         2.0  4.291036e-01  4.645014e+00  4.524825e+00  3.319691e+00
# std          0.0  5.055324e-01  1.467270e+00  2.380551e+00  1.416086e+00
# min          2.0 -1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%          2.0  0.000000e+00  4.000000e+00  1.000000e+00  3.000000e+00
# 50%          2.0  0.000000e+00  5.000000e+00  5.000000e+00  4.000000e+00
# 75%          2.0  1.000000e+00  6.000000e+00  6.000000e+00  4.000000e+00
# max          2.0  1.000000e+00  6.000000e+00  7.000000e+00  6.000000e+00

# %%
train_df.shape
# Out:
# (1975989, 11)

# %%
#Outliers

# %%
#statistic each product id sale in train set

# %%
plt.figure(figsize=(16,8))
train_df['sku_id'].value_counts(normalize=True)[:100].plot(kind='bar',color='darkorange')
plt.title('product sales')
plt.xlabel('product_id')
plt.ylabel('sales')
# Out:
# Text(0, 0.5, 'sales')

# %%
train_df['sku_id'].value_counts(ascending=False)[:5]
# Out:
# 152092    7724
# 37284     5457
# 107331    5407
# 19643     5341
# 232801    5126
# Name: sku_id, dtype: int64

# %%
train_df[train_df['sku_id']==152092]
# Out:
#          cate  user_id  sku_id            action_time  brand  shop_id  type  \
# 9610       69   161965  152092  2018-03-13 11:55:12.0   5277     4005     2
# 9627       69     1092  152092  2018-03-29 17:08:11.0   5277     4005     2
# 9659       69  1204522  152092  2018-02-06 09:09:21.0   5277     4005     2
# 9661       69   333311  152092  2018-04-03 09:28:48.0   5277     4005     2
# 9670       69   640484  152092  2018-02-11 07:39:09.0   5277     4005     2
# ...       ...      ...     ...                    ...    ...      ...   ...
# 1972808    69   257777  152092  2018-03-23 13:43:13.0   5277     4005     2
# 1972846    69   508957  152092  2018-02-05 19:45:08.0   5277     4005     2
# 1972878    69  1337253  152092  2018-03-26 23:43:00.0   5277     4005     2
# 1972879    69  1022656  152092  2018-02-17 19:13:11.0   5277     4005     2
# 1972885    69   462970  152092  2018-03-25 15:46:03.0   5277     4005     2
#
#          sex  age  user_lv_cd  city_level
# 9610     1.0  5.0           5         5.0
# 9627     0.0  6.0           6         4.0
# 9659     0.0  5.0           5         4.0
# 9661     0.0  5.0           1         4.0
# 9670     0.0  6.0           6         4.0
# ...      ...  ...         ...         ...
# 1972808  1.0  6.0           6         1.0
# 1972846  0.0  6.0           1         5.0
# 1972878  0.0  2.0           1         5.0
# 1972879  0.0  5.0           7         5.0
# 1972885  0.0  5.0           1         4.0
#
# [7724 rows x 11 columns]

# %%
#change date form

# %%
train_df['action_time']=pd.to_datetime(train_df['action_time']).dt.strftime('%Y%m%d')
train_df['action_time']
# Out:
# 1          20180302
# 2          20180206
# 3          20180308
# 4          20180205
# 5          20180218
#              ...
# 1978959    20180403
# 1978960    20180304
# 1978961    20180312
# 1978962    20180313
# 1978963    20180211
# Name: action_time, Length: 1975989, dtype: object

# %%
train_df[train_df['sku_id']==152092].value_counts('action_time')
# Out:
# action_time
# 20180328    380
# 20180312    272
# 20180204    253
# 20180228    214
# 20180205    193
#            ...
# 20180218     37
# 20180217     35
# 20180214     31
# 20180216     22
# 20180215     20
# Length: 68, dtype: int64

# %%
plt.figure(figsize=(16,8))
train_df[train_df['sku_id']==152092].value_counts('action_time').plot(kind='bar',color='darkorange')
plt.title('product 152092 sales each day')
plt.xlabel('time')
plt.ylabel('sales')
# Out:
# Text(0, 0.5, 'sales')

# %%
train_df['sku_id'].value_counts(ascending=True)[:10]
# Out:
# 52710     1
# 351916    1
# 376496    1
# 368308    1
# 25092     1
# 29190     1
# 49680     1
# 53778     1
# 39451     1
# 66088     1
# Name: sku_id, dtype: int64

# %%
#change action time to number representing

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
train_df['date_num'] = label_encoder.fit_transform(train_df['action_time'])

# %%
train_df
# Out:
#          cate  user_id  sku_id action_time  brand  shop_id  type  sex  age  \
# 1          79  1008776   31647    20180302  10511     9665     2  0.0  6.0
# 2          79  1569797  141162    20180206   4854       79     2  1.0  5.0
# 3          79  1066676  102904    20180308   1226     7129     2  1.0  6.0
# 4          79  1314628  102417    20180205   5700     1553     2  1.0  5.0
# 5          79   982912  264665    20180218   1898     1182     2  0.0  5.0
# ...       ...      ...     ...         ...    ...      ...   ...  ...  ...
# 1978959     3   254643  126121    20180403   4854     5338     2  1.0  5.0
# 1978960    24  1233285  373243    20180304   2540     4211     2  1.0  6.0
# 1978961    10   138926   42714    20180312   8570     2738     2  0.0  5.0
# 1978962    45   118627   54885    20180313   5309     7400     2  0.0  5.0
# 1978963    31   767401  105868    20180211   8734     7918     2  0.0  5.0
#
#          user_lv_cd  city_level  date_num
# 1                 7         4.0        29
# 2                 5         4.0         5
# 3                 7         1.0        35
# 4                 5         1.0         4
# 5                 5         1.0        17
# ...             ...         ...       ...
# 1978959           1         4.0        61
# 1978960           7         4.0        31
# 1978961           6         5.0        39
# 1978962           1         4.0        40
# 1978963           7         1.0        10
#
# [1975989 rows x 12 columns]

# %%
from itertools import product

# %%
#create certesian tuple cate-sku_id-day_time in train set

# %%
cate_sale_day0=train_df.loc[train_df['date_num']==0,'cate'].unique()
sku_sale_day0=train_df.loc[train_df['date_num']==0,'sku_id'].unique()
day0=list(product(*[cate_sale_day0,sku_sale_day0,[0]]))

# %%
day0[:5]
# Out:
# [(79, 307497, 0),
#  (79, 315374, 0),
#  (79, 299672, 0),
#  (79, 246872, 0),
#  (79, 56948, 0)]

# %%
len(day0)
# Out:
# 1230229

# %%
days=train_df['date_num'].unique()
cartesian=[]
for day in days:
    cate_sale_day=train_df.loc[train_df['date_num']==day,'cate'].unique()
    sku_sale_day=train_df.loc[train_df['date_num']==day,'sku_id'].unique()
    cartesian.append(np.array(list(product(*[cate_sale_day,sku_sale_day,[day]])),dtype='int32'))
cartesian_df=pd.DataFrame(np.vstack(cartesian),columns=['cate','sku_id','date_num'],dtype=np.int32)

# %%
cartesian_df
# Out:
#           cate  sku_id  date_num
# 0           79   31647        29
# 1           79  370012        29
# 2           79  167639        29
# 3           79   66128        29
# 4           79  221695        29
# ...        ...     ...       ...
# 62784518    54  253703        65
# 62784519    54   23596        65
# 62784520    54  308873        65
# 62784521    54  129038        65
# 62784522    54  192762        65
#
# [62784523 rows x 3 columns]

# %%
#calculate the total sale of each product each day

# %%
train_df.insert(train_df.shape[1],'count',1)

# %%
train_df
# Out:
#          cate  user_id  sku_id action_time  brand  shop_id  type  sex  age  \
# 1          79  1008776   31647    20180302  10511     9665     2  0.0  6.0
# 2          79  1569797  141162    20180206   4854       79     2  1.0  5.0
# 3          79  1066676  102904    20180308   1226     7129     2  1.0  6.0
# 4          79  1314628  102417    20180205   5700     1553     2  1.0  5.0
# 5          79   982912  264665    20180218   1898     1182     2  0.0  5.0
# ...       ...      ...     ...         ...    ...      ...   ...  ...  ...
# 1978959     3   254643  126121    20180403   4854     5338     2  1.0  5.0
# 1978960    24  1233285  373243    20180304   2540     4211     2  1.0  6.0
# 1978961    10   138926   42714    20180312   8570     2738     2  0.0  5.0
# 1978962    45   118627   54885    20180313   5309     7400     2  0.0  5.0
# 1978963    31   767401  105868    20180211   8734     7918     2  0.0  5.0
#
#          user_lv_cd  city_level  date_num  count
# 1                 7         4.0        29      1
# 2                 5         4.0         5      1
# 3                 7         1.0        35      1
# 4                 5         1.0         4      1
# 5                 5         1.0        17      1
# ...             ...         ...       ...    ...
# 1978959           1         4.0        61      1
# 1978960           7         4.0        31      1
# 1978961           6         5.0        39      1
# 1978962           1         4.0        40      1
# 1978963           7         1.0        10      1
#
# [1975989 rows x 13 columns]

# %%
x=train_df.groupby(['cate','sku_id','date_num'])['count'].sum().rename('sales').reset_index()
x
# Out:
#         cate  sku_id  date_num  sales
# 0          1    2304         6      1
# 1          1    3539        21      1
# 2          1    3539        39      1
# 3          1    3539        42      1
# 4          1    3539        54      1
# ...      ...     ...       ...    ...
# 809774    81  378373        49      1
# 809775    81  378373        55      7
# 809776    81  378373        59      1
# 809777    81  378395        65      1
# 809778    81  378435        45      1
#
# [809779 rows x 4 columns]

# %%
#merge cartesian list and sale column

# %%
train_new=pd.merge(cartesian_df,x,on=['cate','sku_id','date_num'],how='left').fillna(0)

# %%
train_new
# Out:
#           cate  sku_id  date_num  sales
# 0           79   31647        29    4.0
# 1           79  370012        29    1.0
# 2           79  167639        29    9.0
# 3           79   66128        29    3.0
# 4           79  221695        29   12.0
# ...        ...     ...       ...    ...
# 62784518    54  253703        65    0.0
# 62784519    54   23596        65    0.0
# 62784520    54  308873        65    0.0
# 62784521    54  129038        65    0.0
# 62784522    54  192762        65    0.0
#
# [62784523 rows x 4 columns]

# %%
#srot the dataframe

# %%
train_new.sort_values(['date_num','cate','sku_id'],inplace=True)
train_new
# Out:
#           cate  sku_id  date_num  sales
# 5950473      1      17         0    0.0
# 5953982      1      41         0    0.0
# 5949718      1      76         0    0.0
# 5950103      1      99         0    0.0
# 5960446      1     115         0    0.0
# ...        ...     ...       ...    ...
# 60343629    81  378379        67    0.0
# 60347256    81  378384        67    0.0
# 60350187    81  378404        67    0.0
# 60348024    81  378410        67    0.0
# 60353590    81  378414        67    0.0
#
# [62784523 rows x 4 columns]

# %%
train_new.describe()
# Out:
#                cate        sku_id      date_num         sales
# count  6.278452e+07  6.278452e+07  6.278452e+07  6.278452e+07
# mean   4.193265e+01  1.892270e+05  3.470942e+01  3.147255e-02
# std    2.321453e+01  1.090832e+05  1.962471e+01  9.314236e-01
# min    1.000000e+00  1.300000e+01  0.000000e+00  0.000000e+00
# 25%    2.300000e+01  9.464500e+04  2.100000e+01  0.000000e+00
# 50%    4.200000e+01  1.888480e+05  3.500000e+01  0.000000e+00
# 75%    6.200000e+01  2.836780e+05  5.100000e+01  0.000000e+00
# max    8.100000e+01  3.784560e+05  6.700000e+01  1.253000e+03

# %%
#data clean

# %%
train_new['sales'].max()
# Out:
# 1253.0

# %%
train_new[train_new['sales']==1253]
# Out:
#          cate  sku_id  date_num   sales
# 1137497     7  258625         5  1253.0

# %%
x=train_new[train_new['sku_id']==258625].sort_values(['sales'])
x
# Out:
#           cate  sku_id  date_num   sales
# 2067517      1  258625         5     0.0
# 45011500    64  258625        50     0.0
# 45787564    65  258625        50     0.0
# 45569296    66  258625        50     0.0
# 45035752    67  258625        50     0.0
# ...        ...     ...       ...     ...
# 7813345      7  258625        31   180.0
# 29199375     7  258625        30   193.0
# 64758        7  258625        29   245.0
# 28210609     7  258625         6   375.0
# 1137497      7  258625         5  1253.0
#
# [3036 rows x 4 columns]

# %%
#we find the cate 7 product 285625 in day 5 have much more sales than other days.
#it can be thought outlier and we delete it

# %%
train_new=train_new.drop(train_new[(train_new['cate']==7)&(train_new['sku_id']==258625)&(train_new['date_num']==5)&(train_new['sales']==1253)].index)

# %%
x=train_new.sort_values(['sales'])
x
# Out:
#           cate  sku_id  date_num   sales
# 5950473      1      17         0     0.0
# 10583818    30  105868        46     0.0
# 10586802    30  105870        46     0.0
# 10586878    30  105876        46     0.0
# 10592888    30  105927        46     0.0
# ...        ...     ...       ...     ...
# 16498324    67  272313        52   724.0
# 34598474    23  312817        49   828.0
# 4908364      7  288370         0   873.0
# 16336666    81  147902        52  1166.0
# 1137497      7  258625         5  1253.0
#
# [62784523 rows x 4 columns]

# %%
x=train_new[train_new['sku_id']==147902].sort_values(['sales'])
x
# Out:
#           cate  sku_id  date_num   sales
# 3198948      1  147902        35     0.0
# 56684552    16  147902        61     0.0
# 56160898    17  147902        61     0.0
# 56246144    19  147902        61     0.0
# 56453170    20  147902        61     0.0
# ...        ...     ...       ...     ...
# 56319212    81  147902        61     2.0
# 62211291    81  147902        65     2.0
# 52636621    81  147902        63     4.0
# 18313423    81  147902        55     4.0
# 16336666    81  147902        52  1166.0
#
# [1085 rows x 4 columns]

# %%
train_new=train_new.drop(train_new[(train_new['cate']==81)&(train_new['sku_id']==147902)&(train_new['date_num']==52)&(train_new['sales']==1166)].index)

# %%
x=train_new[train_new['sku_id']==288370].sort_values(['sales'])
x
# Out:
#           cate  sku_id  date_num  sales
# 5946869      1  288370         0    0.0
# 37346119    48  288370        42    0.0
# 37359524    49  288370        42    0.0
# 37453359    50  288370        42    0.0
# 36796514    51  288370        42    0.0
# ...        ...     ...       ...    ...
# 42327961     7  288370        43    2.0
# 17281687     7  288370        34    2.0
# 8903371      7  288370        41    3.0
# 36474794     7  288370        42    3.0
# 4908364      7  288370         0  873.0
#
# [781 rows x 4 columns]

# %%
train_new=train_new.drop(train_new[(train_new['cate']==7)&(train_new['sku_id']==288370)&(train_new['date_num']==0)&(train_new['sales']==873)].index)

# %%
train_new
# Out:
#           cate  sku_id  date_num  sales
# 5950473      1      17         0    0.0
# 5953982      1      41         0    0.0
# 5949718      1      76         0    0.0
# 5950103      1      99         0    0.0
# 5960446      1     115         0    0.0
# ...        ...     ...       ...    ...
# 60343629    81  378379        67    0.0
# 60347256    81  378384        67    0.0
# 60350187    81  378404        67    0.0
# 60348024    81  378410        67    0.0
# 60353590    81  378414        67    0.0
#
# [62784520 rows x 4 columns]

# %%
x=train_new[train_new['sku_id']==312817].sort_values(['sales'])
x
# Out:
#           cate  sku_id  date_num  sales
# 36433761     1  312817        48    0.0
# 53158523    49  312817        63    0.0
# 52503155    51  312817        63    0.0
# 52901057    52  312817        63    0.0
# 52924463    53  312817        63    0.0
# ...        ...     ...       ...    ...
# 11330330    23  312817        54    1.0
# 54406167    23  312817        60    1.0
# 55171071    23  312817        66    2.0
# 35746245    23  312817        48  503.0
# 34598474    23  312817        49  828.0
#
# [778 rows x 4 columns]

# %%
train_new=train_new.drop(train_new[(train_new['cate']==23)&(train_new['sku_id']==312817)&(train_new['date_num']==48)&(train_new['sales']==503)].index)
train_new=train_new.drop(train_new[(train_new['cate']==23)&(train_new['sku_id']==312817)&(train_new['date_num']==49)&(train_new['sales']==828)].index)

# %%
x=train_new[train_new['sku_id']==272313].sort_values(['sales'])
x
# Out:
#           cate  sku_id  date_num  sales
# 5950398      1  272313         0    0.0
# 36384281    58  272313        48    0.0
# 36319421    59  272313        48    0.0
# 36202673    60  272313        48    0.0
# 35956205    61  272313        48    0.0
# ...        ...     ...       ...    ...
# 57096860    67  272313        58    9.0
# 53378854    67  272313        57    9.0
# 18537313    67  272313        55   10.0
# 46365053    67  272313        53   99.0
# 16498324    67  272313        52  724.0
#
# [4425 rows x 4 columns]

# %%
train_new=train_new.drop(train_new[(train_new['cate']==67)&(train_new['sku_id']==272313)&(train_new['date_num']==52)&(train_new['sales']==724)].index)

# %%
train_new
# Out:
#           cate  sku_id  date_num  sales
# 5950473      1      17         0    0.0
# 5953982      1      41         0    0.0
# 5949718      1      76         0    0.0
# 5950103      1      99         0    0.0
# 5960446      1     115         0    0.0
# ...        ...     ...       ...    ...
# 60343629    81  378379        67    0.0
# 60347256    81  378384        67    0.0
# 60350187    81  378404        67    0.0
# 60348024    81  378410        67    0.0
# 60353590    81  378414        67    0.0
#
# [62784517 rows x 4 columns]

# %%
#deal with test data

# %%
test_df.shape
# Out:
# (184682, 11)

# %%
test_df.dropna(how='any',inplace=True)

# %%
test_df.shape
# Out:
# (184456, 11)

# %%
test_df['action_time']=pd.to_datetime(test_df['action_time']).dt.strftime('%Y%m%d')
test_df['action_time']
# Out:
# 2         20180410
# 3         20180412
# 4         20180410
# 5         20180411
# 6         20180410
#             ...
# 184677    20180410
# 184678    20180411
# 184679    20180415
# 184680    20180413
# 184681    20180413
# Name: action_time, Length: 184456, dtype: object

# %%
label_encoder = preprocessing.LabelEncoder()
test_df['date_num'] = label_encoder.fit_transform(test_df['action_time'])
test_df
# Out:
#         cate  user_id  sku_id action_time  brand  shop_id  type  sex  age  \
# 2         27  1074877  134144    20180410   6588     3663     2  0.0  5.0
# 3         79   158811  114345    20180412   6574     4071     2  1.0  5.0
# 4         72   852571  219951    20180410   3746     7196     2 -1.0  5.0
# 5         79   817501  151783    20180411   9268     1259     2  0.0  6.0
# 6         27  1306886  239072    20180410  10874     8771     2  1.0  6.0
# ...      ...      ...     ...         ...    ...      ...   ...  ...  ...
# 184677    43   681514   37925    20180410   2484     4019     2  0.0  5.0
# 184678    34  1311043   86452    20180411   2484     9649     2  0.0  2.0
# 184679    81   777706  281779    20180415    265     4222     2  1.0  5.0
# 184680    41   720945  272638    20180413   3263     1315     2  1.0  6.0
# 184681    20   341637  375223    20180413  11114      776     2  0.0  4.0
#
#         user_lv_cd  city_level  date_num
# 2                7         1.0         0
# 3                5         1.0         2
# 4                6         1.0         0
# 5                7         6.0         1
# 6                1         4.0         0
# ...            ...         ...       ...
# 184677           5         5.0         0
# 184678           7         4.0         1
# 184679           5         4.0         5
# 184680           1         1.0         3
# 184681           6         5.0         3
#
# [184456 rows x 12 columns]

# %%
days=test_df['date_num'].unique()
cartesian=[]
for day in days:
    cate_sale_day=test_df.loc[test_df['date_num']==day,'cate'].unique()
    sku_sale_day=test_df.loc[test_df['date_num']==day,'sku_id'].unique()
    cartesian.append(np.array(list(product(*[cate_sale_day,sku_sale_day,[day]])),dtype='int32'))
cartesian_df=pd.DataFrame(np.vstack(cartesian),columns=['cate','sku_id','date_num'],dtype=np.int32)

# %%
cartesian_df
# Out:
#          cate  sku_id  date_num
# 0          27  134144         0
# 1          27  219951         0
# 2          27  239072         0
# 3          27  101918         0
# 4          27    9275         0
# ...       ...     ...       ...
# 6029742    50   90779         3
# 6029743    50   40268         3
# 6029744    50  143840         3
# 6029745    50  265852         3
# 6029746    50   25310         3
#
# [6029747 rows x 3 columns]

# %%
test_df.insert(test_df.shape[1],'count',1)

# %%
test_df
# Out:
#         cate  user_id  sku_id action_time  brand  shop_id  type  sex  age  \
# 2         27  1074877  134144    20180410   6588     3663     2  0.0  5.0
# 3         79   158811  114345    20180412   6574     4071     2  1.0  5.0
# 4         72   852571  219951    20180410   3746     7196     2 -1.0  5.0
# 5         79   817501  151783    20180411   9268     1259     2  0.0  6.0
# 6         27  1306886  239072    20180410  10874     8771     2  1.0  6.0
# ...      ...      ...     ...         ...    ...      ...   ...  ...  ...
# 184677    43   681514   37925    20180410   2484     4019     2  0.0  5.0
# 184678    34  1311043   86452    20180411   2484     9649     2  0.0  2.0
# 184679    81   777706  281779    20180415    265     4222     2  1.0  5.0
# 184680    41   720945  272638    20180413   3263     1315     2  1.0  6.0
# 184681    20   341637  375223    20180413  11114      776     2  0.0  4.0
#
#         user_lv_cd  city_level  date_num  count
# 2                7         1.0         0      1
# 3                5         1.0         2      1
# 4                6         1.0         0      1
# 5                7         6.0         1      1
# 6                1         4.0         0      1
# ...            ...         ...       ...    ...
# 184677           5         5.0         0      1
# 184678           7         4.0         1      1
# 184679           5         4.0         5      1
# 184680           1         1.0         3      1
# 184681           6         5.0         3      1
#
# [184456 rows x 13 columns]

# %%
x=test_df.groupby(['cate','sku_id','date_num'])['count'].sum().rename('sales').reset_index()
x
# Out:
#        cate  sku_id  date_num  sales
# 0         1   14895         2      1
# 1         1   18461         0      1
# 2         1   25504         5      1
# 3         1   41819         0      1
# 4         1   41819         3      1
# ...     ...     ...       ...    ...
# 77473    81  376196         3      1
# 77474    81  376348         4      1
# 77475    81  376730         1      1
# 77476    81  376979         5      1
# 77477    81  377280         5      1
#
# [77478 rows x 4 columns]

# %%
test_new=pd.merge(cartesian_df,x,on=['cate','sku_id','date_num'],how='left').fillna(0)
test_new
# Out:
#          cate  sku_id  date_num  sales
# 0          27  134144         0    2.0
# 1          27  219951         0    0.0
# 2          27  239072         0    1.0
# 3          27  101918         0    0.0
# 4          27    9275         0    0.0
# ...       ...     ...       ...    ...
# 6029742    50   90779         3    0.0
# 6029743    50   40268         3    0.0
# 6029744    50  143840         3    0.0
# 6029745    50  265852         3    0.0
# 6029746    50   25310         3    0.0
#
# [6029747 rows x 4 columns]

# %%
test_new.sort_values(['date_num','cate','sku_id'],inplace=True)
test_new
# Out:
#          cate  sku_id  date_num  sales
# 849241      1      59         0    0.0
# 851035      1      61         0    0.0
# 848244      1      75         0    0.0
# 843376      1     115         0    0.0
# 847658      1     175         0    0.0
# ...       ...     ...       ...    ...
# 3229037    81  378341         5    0.0
# 3229656    81  378365         5    0.0
# 3231998    81  378378         5    0.0
# 3227079    81  378384         5    0.0
# 3234674    81  378410         5    0.0
#
# [6029747 rows x 4 columns]

# %%
train_feature = train_new[train_new.date_num<51].drop(['sales'], axis=1)

train_label = train_new[train_new.date_num<51]['sales']

# %%
val_feature = train_new[train_new.date_num>50].drop(['sales'], axis=1)

val_label = train_new[train_new.date_num >50]['sales']

# %%
test_feature = test_new.drop(['sales'], axis=1)

# %%
import gc
gc.collect()
# Out:
# 20

# %%
from xgboost import XGBRegressor

# %%
model = XGBRegressor(n_estimators=3000,
                     max_depth=10,
                     colsample_bytree=0.5, 
                     subsample=0.5, 
                     learning_rate = 0.01
                    )

# %%
model.fit(train_feature.values, train_label.values, 
          eval_metric="rmse", 
          eval_set=[(train_feature.values, train_label.values), (val_feature.values, val_label.values)], 
          verbose=True, 
          early_stopping_rounds = 50)
# Out:
# [0]	validation_0-rmse:0.92765	validation_1-rmse:1.05439
# [1]	validation_0-rmse:0.92748	validation_1-rmse:1.05404
# [2]	validation_0-rmse:0.92749	validation_1-rmse:1.05392
# [3]	validation_0-rmse:0.92698	validation_1-rmse:1.05259
# [4]	validation_0-rmse:0.92700	validation_1-rmse:1.05251
# [5]	validation_0-rmse:0.92688	validation_1-rmse:1.05218
# [6]	validation_0-rmse:0.92688	validation_1-rmse:1.05208
# [7]	validation_0-rmse:0.92514	validation_1-rmse:1.04749
# [8]	validation_0-rmse:0.92505	validation_1-rmse:1.04728
# [9]	validation_0-rmse:0.92504	validation_1-rmse:1.04698
# [10]	validation_0-rmse:0.92481	validation_1-rmse:1.04627
# [11]	validation_0-rmse:0.92452	validation_1-rmse:1.04539
# [12]	validation_0-rmse:0.92437	validation_1-rmse:1.04506
# [13]	validation_0-rmse:0.92434	validation_1-rmse:1.04490
# [14]	validation_0-rmse:0.92269	validation_1-rmse:1.04063
# [15]	validation_0-rmse:0.91789	validation_1-rmse:1.02348
# [16]	validation_0-rmse:0.91737	validation_1-rmse:1.02200
# [17]	validation_0-rmse:0.91691	validation_1-rmse:1.02068
# [18]	validation_0-rmse:0.91674	validation_1-rmse:1.01957
# [19]	validation_0-rmse:0.91646	validation_1-rmse:1.01847
# [20]	validation_0-rmse:0.91640	validation_1-rmse:1.01829
# [21]	validation_0-rmse:0.91632	validation_1-rmse:1.01813
# [22]	validation_0-rmse:0.91628	validation_1-rmse:1.01796
# [23]	validation_0-rmse:0.91631	validation_1-rmse:1.01774
# [24]	validation_0-rmse:0.91492	validation_1-rmse:1.01378
# [25]	validation_0-rmse:0.91455	validation_1-rmse:1.01216
# [26]	validation_0-rmse:0.91461	validation_1-rmse:1.01175
# [27]	validation_0-rmse:0.91457	validation_1-rmse:1.01154
# [28]	validation_0-rmse:0.91451	validation_1-rmse:1.01123
# [29]	validation_0-rmse:0.91450	validation_1-rmse:1.01105
# [30]	validation_0-rmse:0.91430	validation_1-rmse:1.00997
# [31]	validation_0-rmse:0.91427	validation_1-rmse:1.00977
# [32]	validation_0-rmse:0.91427	validation_1-rmse:1.00970
# [33]	validation_0-rmse:0.91414	validation_1-rmse:1.00953
# [34]	validation_0-rmse:0.91414	validation_1-rmse:1.00938
# [35]	validation_0-rmse:0.91358	validation_1-rmse:1.00894
# [36]	validation_0-rmse:0.89183	validation_1-rmse:0.99536
# [37]	validation_0-rmse:0.88499	validation_1-rmse:0.99139
# [38]	validation_0-rmse:0.88132	validation_1-rmse:0.98955
# [39]	validation_0-rmse:0.87950	validation_1-rmse:0.98837
# [40]	validation_0-rmse:0.87883	validation_1-rmse:0.98800
# [41]	validation_0-rmse:0.87882	validation_1-rmse:0.98792
# [42]	validation_0-rmse:0.87803	validation_1-rmse:0.98760
# [43]	validation_0-rmse:0.87662	validation_1-rmse:0.98620
# [44]	validation_0-rmse:0.87652	validation_1-rmse:0.98590
# [45]	validation_0-rmse:0.87532	validation_1-rmse:0.98535
# [46]	validation_0-rmse:0.87499	validation_1-rmse:0.98514
# [47]	validation_0-rmse:0.87487	validation_1-rmse:0.98502
# [48]	validation_0-rmse:0.87489	validation_1-rmse:0.98497
# [49]	validation_0-rmse:0.87489	validation_1-rmse:0.98494
# [50]	validation_0-rmse:0.87490	validation_1-rmse:0.98487
# [51]	validation_0-rmse:0.87366	validation_1-rmse:0.98254
# [52]	validation_0-rmse:0.87299	validation_1-rmse:0.98101
# [53]	validation_0-rmse:0.87286	validation_1-rmse:0.98036
# [54]	validation_0-rmse:0.87269	validation_1-rmse:0.97978
# [55]	validation_0-rmse:0.87251	validation_1-rmse:0.97942
# [56]	validation_0-rmse:0.87239	validation_1-rmse:0.97907
# [57]	validation_0-rmse:0.87235	validation_1-rmse:0.97884
# [58]	validation_0-rmse:0.87234	validation_1-rmse:0.97873
# [59]	validation_0-rmse:0.87235	validation_1-rmse:0.97866
# [60]	validation_0-rmse:0.87232	validation_1-rmse:0.97854
# [61]	validation_0-rmse:0.87224	validation_1-rmse:0.97800
# [62]	validation_0-rmse:0.87212	validation_1-rmse:0.97754
# [63]	validation_0-rmse:0.87206	validation_1-rmse:0.97743
# [64]	validation_0-rmse:0.87206	validation_1-rmse:0.97736
# [65]	validation_0-rmse:0.87205	validation_1-rmse:0.97727
# [66]	validation_0-rmse:0.87196	validation_1-rmse:0.97711
# [67]	validation_0-rmse:0.87193	validation_1-rmse:0.97706
# [68]	validation_0-rmse:0.87192	validation_1-rmse:0.97706
# [69]	validation_0-rmse:0.87194	validation_1-rmse:0.97700
# [70]	validation_0-rmse:0.87196	validation_1-rmse:0.97694
# [71]	validation_0-rmse:0.87195	validation_1-rmse:0.97692
# [72]	validation_0-rmse:0.87094	validation_1-rmse:0.97411
# [73]	validation_0-rmse:0.86857	validation_1-rmse:0.96636
# [74]	validation_0-rmse:0.86685	validation_1-rmse:0.96148
# [75]	validation_0-rmse:0.86578	validation_1-rmse:0.95822
# [76]	validation_0-rmse:0.86535	validation_1-rmse:0.95727
# [77]	validation_0-rmse:0.86495	validation_1-rmse:0.95629
# [78]	validation_0-rmse:0.86460	validation_1-rmse:0.95523
# [79]	validation_0-rmse:0.86435	validation_1-rmse:0.95463
# [80]	validation_0-rmse:0.86409	validation_1-rmse:0.95419
# [81]	validation_0-rmse:0.86398	validation_1-rmse:0.95403
# [82]	validation_0-rmse:0.86377	validation_1-rmse:0.95367
# [83]	validation_0-rmse:0.86368	validation_1-rmse:0.95349
# [84]	validation_0-rmse:0.86369	validation_1-rmse:0.95341
# [85]	validation_0-rmse:0.86369	validation_1-rmse:0.95337
# [86]	validation_0-rmse:0.86362	validation_1-rmse:0.95316
# [87]	validation_0-rmse:0.86356	validation_1-rmse:0.95301
# [88]	validation_0-rmse:0.86347	validation_1-rmse:0.95264
# [89]	validation_0-rmse:0.86337	validation_1-rmse:0.95230
# [90]	validation_0-rmse:0.86331	validation_1-rmse:0.95211
# [91]	validation_0-rmse:0.86330	validation_1-rmse:0.95199
# [92]	validation_0-rmse:0.86334	validation_1-rmse:0.95192
# [93]	validation_0-rmse:0.86334	validation_1-rmse:0.95183
# [94]	validation_0-rmse:0.86323	validation_1-rmse:0.95128
# [95]	validation_0-rmse:0.86313	validation_1-rmse:0.95088
# [96]	validation_0-rmse:0.86313	validation_1-rmse:0.95072
# [97]	validation_0-rmse:0.86310	validation_1-rmse:0.95065
# [98]	validation_0-rmse:0.86306	validation_1-rmse:0.95059
# [99]	validation_0-rmse:0.86306	validation_1-rmse:0.95054
# [100]	validation_0-rmse:0.86309	validation_1-rmse:0.95055
# [101]	validation_0-rmse:0.86301	validation_1-rmse:0.95044
# [102]	validation_0-rmse:0.86294	validation_1-rmse:0.95022
# [103]	validation_0-rmse:0.86290	validation_1-rmse:0.94996
# [104]	validation_0-rmse:0.86284	validation_1-rmse:0.94963
# [105]	validation_0-rmse:0.86286	validation_1-rmse:0.94959
# [106]	validation_0-rmse:0.86290	validation_1-rmse:0.94960
# [107]	validation_0-rmse:0.86294	validation_1-rmse:0.94961
# [108]	validation_0-rmse:0.86296	validation_1-rmse:0.94960
# [109]	validation_0-rmse:0.86276	validation_1-rmse:0.94927
# [110]	validation_0-rmse:0.86230	validation_1-rmse:0.94829
# [111]	validation_0-rmse:0.86183	validation_1-rmse:0.94739
# [112]	validation_0-rmse:0.86153	validation_1-rmse:0.94672
# [113]	validation_0-rmse:0.86133	validation_1-rmse:0.94633
# [114]	validation_0-rmse:0.86113	validation_1-rmse:0.94596
# [115]	validation_0-rmse:0.86095	validation_1-rmse:0.94546
# [116]	validation_0-rmse:0.86087	validation_1-rmse:0.94517
# [117]	validation_0-rmse:0.86083	validation_1-rmse:0.94497
# [118]	validation_0-rmse:0.86080	validation_1-rmse:0.94473
# [119]	validation_0-rmse:0.86080	validation_1-rmse:0.94459
# [120]	validation_0-rmse:0.86077	validation_1-rmse:0.94445
# [121]	validation_0-rmse:0.86073	validation_1-rmse:0.94428
# [122]	validation_0-rmse:0.86074	validation_1-rmse:0.94419
# [123]	validation_0-rmse:0.86075	validation_1-rmse:0.94419
# [124]	validation_0-rmse:0.86077	validation_1-rmse:0.94417
# [125]	validation_0-rmse:0.86076	validation_1-rmse:0.94409
# [126]	validation_0-rmse:0.86072	validation_1-rmse:0.94402
# [127]	validation_0-rmse:0.86069	validation_1-rmse:0.94394
# [128]	validation_0-rmse:0.86068	validation_1-rmse:0.94388
# [129]	validation_0-rmse:0.86067	validation_1-rmse:0.94384
# [130]	validation_0-rmse:0.86066	validation_1-rmse:0.94378
# [131]	validation_0-rmse:0.86065	validation_1-rmse:0.94367
# [132]	validation_0-rmse:0.86066	validation_1-rmse:0.94359
# [133]	validation_0-rmse:0.86068	validation_1-rmse:0.94358
# [134]	validation_0-rmse:0.86069	validation_1-rmse:0.94357
# [135]	validation_0-rmse:0.86072	validation_1-rmse:0.94357
# [136]	validation_0-rmse:0.86076	validation_1-rmse:0.94356
# [137]	validation_0-rmse:0.86080	validation_1-rmse:0.94356
# [138]	validation_0-rmse:0.86084	validation_1-rmse:0.94354
# [139]	validation_0-rmse:0.86084	validation_1-rmse:0.94352
# [140]	validation_0-rmse:0.86087	validation_1-rmse:0.94348
# [141]	validation_0-rmse:0.86090	validation_1-rmse:0.94346
# [142]	validation_0-rmse:0.86094	validation_1-rmse:0.94347
# [143]	validation_0-rmse:0.86098	validation_1-rmse:0.94348
# [144]	validation_0-rmse:0.86102	validation_1-rmse:0.94348
# [145]	validation_0-rmse:0.86105	validation_1-rmse:0.94349
# [146]	validation_0-rmse:0.86109	validation_1-rmse:0.94350
# [147]	validation_0-rmse:0.86110	validation_1-rmse:0.94349
# [148]	validation_0-rmse:0.86112	validation_1-rmse:0.94344
# [149]	validation_0-rmse:0.86110	validation_1-rmse:0.94331
# [150]	validation_0-rmse:0.86108	validation_1-rmse:0.94310
# [151]	validation_0-rmse:0.86107	validation_1-rmse:0.94293
# [152]	validation_0-rmse:0.86106	validation_1-rmse:0.94277
# [153]	validation_0-rmse:0.86105	validation_1-rmse:0.94266
# [154]	validation_0-rmse:0.86104	validation_1-rmse:0.94255
# [155]	validation_0-rmse:0.86102	validation_1-rmse:0.94246
# [156]	validation_0-rmse:0.86100	validation_1-rmse:0.94236
# [157]	validation_0-rmse:0.86099	validation_1-rmse:0.94227
# [158]	validation_0-rmse:0.86099	validation_1-rmse:0.94222
# [159]	validation_0-rmse:0.86100	validation_1-rmse:0.94219
# [160]	validation_0-rmse:0.86101	validation_1-rmse:0.94217
# [161]	validation_0-rmse:0.86102	validation_1-rmse:0.94217
# [162]	validation_0-rmse:0.86103	validation_1-rmse:0.94217
# [163]	validation_0-rmse:0.86104	validation_1-rmse:0.94218
# [164]	validation_0-rmse:0.86104	validation_1-rmse:0.94217
# [165]	validation_0-rmse:0.86106	validation_1-rmse:0.94218
# [166]	validation_0-rmse:0.86106	validation_1-rmse:0.94217
# [167]	validation_0-rmse:0.86108	validation_1-rmse:0.94217
# [168]	validation_0-rmse:0.86110	validation_1-rmse:0.94216
# [169]	validation_0-rmse:0.86111	validation_1-rmse:0.94216
# [170]	validation_0-rmse:0.86113	validation_1-rmse:0.94216
# [171]	validation_0-rmse:0.86114	validation_1-rmse:0.94216
# [172]	validation_0-rmse:0.86116	validation_1-rmse:0.94217
# [173]	validation_0-rmse:0.86116	validation_1-rmse:0.94217
# [174]	validation_0-rmse:0.86117	validation_1-rmse:0.94217
# [175]	validation_0-rmse:0.86118	validation_1-rmse:0.94217
# [176]	validation_0-rmse:0.86120	validation_1-rmse:0.94217
# [177]	validation_0-rmse:0.86122	validation_1-rmse:0.94218
# [178]	validation_0-rmse:0.86123	validation_1-rmse:0.94219
# [179]	validation_0-rmse:0.86126	validation_1-rmse:0.94220
# [180]	validation_0-rmse:0.86129	validation_1-rmse:0.94222
# [181]	validation_0-rmse:0.86130	validation_1-rmse:0.94223
# [182]	validation_0-rmse:0.86132	validation_1-rmse:0.94224
# [183]	validation_0-rmse:0.86134	validation_1-rmse:0.94225
# [184]	validation_0-rmse:0.86136	validation_1-rmse:0.94226
# [185]	validation_0-rmse:0.86136	validation_1-rmse:0.94226
# [186]	validation_0-rmse:0.86136	validation_1-rmse:0.94226
# [187]	validation_0-rmse:0.86135	validation_1-rmse:0.94226
# [188]	validation_0-rmse:0.86134	validation_1-rmse:0.94225
# [189]	validation_0-rmse:0.86133	validation_1-rmse:0.94222
# [190]	validation_0-rmse:0.86132	validation_1-rmse:0.94220
# [191]	validation_0-rmse:0.86131	validation_1-rmse:0.94216
# [192]	validation_0-rmse:0.86131	validation_1-rmse:0.94214
# [193]	validation_0-rmse:0.86131	validation_1-rmse:0.94212
# [194]	validation_0-rmse:0.86131	validation_1-rmse:0.94210
# [195]	validation_0-rmse:0.86131	validation_1-rmse:0.94209
# [196]	validation_0-rmse:0.86132	validation_1-rmse:0.94208
# [197]	validation_0-rmse:0.86132	validation_1-rmse:0.94208
# [198]	validation_0-rmse:0.86134	validation_1-rmse:0.94209
# [199]	validation_0-rmse:0.86135	validation_1-rmse:0.94210
# [200]	validation_0-rmse:0.86136	validation_1-rmse:0.94210
# [201]	validation_0-rmse:0.86137	validation_1-rmse:0.94211
# [202]	validation_0-rmse:0.86138	validation_1-rmse:0.94212
# [203]	validation_0-rmse:0.86140	validation_1-rmse:0.94213
# [204]	validation_0-rmse:0.86141	validation_1-rmse:0.94215
# [205]	validation_0-rmse:0.86142	validation_1-rmse:0.94216
# [206]	validation_0-rmse:0.86142	validation_1-rmse:0.94215
# [207]	validation_0-rmse:0.86144	validation_1-rmse:0.94217
# [208]	validation_0-rmse:0.86145	validation_1-rmse:0.94218
# [209]	validation_0-rmse:0.86145	validation_1-rmse:0.94218
# [210]	validation_0-rmse:0.86146	validation_1-rmse:0.94218
# [211]	validation_0-rmse:0.86147	validation_1-rmse:0.94219
# [212]	validation_0-rmse:0.86148	validation_1-rmse:0.94220
# [213]	validation_0-rmse:0.86150	validation_1-rmse:0.94221
# [214]	validation_0-rmse:0.86151	validation_1-rmse:0.94222
# [215]	validation_0-rmse:0.86152	validation_1-rmse:0.94223
# [216]	validation_0-rmse:0.86153	validation_1-rmse:0.94224
# [217]	validation_0-rmse:0.86153	validation_1-rmse:0.94224
# [218]	validation_0-rmse:0.86154	validation_1-rmse:0.94225
# [219]	validation_0-rmse:0.86154	validation_1-rmse:0.94225
# [220]	validation_0-rmse:0.86155	validation_1-rmse:0.94225
# [221]	validation_0-rmse:0.86155	validation_1-rmse:0.94226
# [222]	validation_0-rmse:0.86156	validation_1-rmse:0.94227
# [223]	validation_0-rmse:0.86158	validation_1-rmse:0.94228
# [224]	validation_0-rmse:0.86158	validation_1-rmse:0.94228
# [225]	validation_0-rmse:0.86159	validation_1-rmse:0.94228
# [226]	validation_0-rmse:0.86160	validation_1-rmse:0.94229
# [227]	validation_0-rmse:0.86161	validation_1-rmse:0.94229
# [228]	validation_0-rmse:0.86161	validation_1-rmse:0.94229
# [229]	validation_0-rmse:0.86162	validation_1-rmse:0.94229
# [230]	validation_0-rmse:0.86163	validation_1-rmse:0.94228
# [231]	validation_0-rmse:0.86164	validation_1-rmse:0.94228
# [232]	validation_0-rmse:0.86166	validation_1-rmse:0.94229
# [233]	validation_0-rmse:0.86167	validation_1-rmse:0.94229
# [234]	validation_0-rmse:0.86168	validation_1-rmse:0.94229
# [235]	validation_0-rmse:0.86169	validation_1-rmse:0.94229
# [236]	validation_0-rmse:0.86171	validation_1-rmse:0.94229
# [237]	validation_0-rmse:0.86172	validation_1-rmse:0.94230
# [238]	validation_0-rmse:0.86174	validation_1-rmse:0.94231
# [239]	validation_0-rmse:0.86174	validation_1-rmse:0.94232
# [240]	validation_0-rmse:0.86176	validation_1-rmse:0.94232
# [241]	validation_0-rmse:0.86177	validation_1-rmse:0.94233
# [242]	validation_0-rmse:0.86178	validation_1-rmse:0.94234
# [243]	validation_0-rmse:0.86180	validation_1-rmse:0.94235
# [244]	validation_0-rmse:0.86180	validation_1-rmse:0.94235
# [245]	validation_0-rmse:0.86182	validation_1-rmse:0.94236
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.5, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=10,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=3000, n_jobs=6, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=0.5,
#              tree_method='approx', validate_parameters=1, verbosity=None)

# %%
y_pred = model.predict(test_feature.values)

# %%
y_pred
# Out:
# array([0.08496528, 0.08496528, 0.08496528, ..., 0.13682356, 0.13682356,
#        0.13682356], dtype=float32)

# %%
test_feature['Pred'] = y_pred
test_feature.to_csv('/Users/charles/Desktop/consumer/Prediction_next_week.csv', index=False)
